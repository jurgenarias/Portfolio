# %% [markdown]
# #### Reading the csv files

# %%
train_a = pd.read_csv('../datasets/train_a.csv')

# %%
test_a = pd.read_csv('../datasets/test_a.csv')

# %%
train_v = pd.read_csv('../datasets/train_data_for_visualizations.csv')

# %% [markdown]
# #### Importing everything

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV

# %matplotlib inline

# %% [markdown]
# #### Some needed code for better visualization

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
# return false;
# }

# %%
pd.set_option('display.min_rows', 60)  # Changing output display options
pd.set_option('display.max_rows', 600)  # Changing output display options

# %% [markdown]
# # Exploratory Visualizations

# %% [markdown]
# #### Looking at the pretty heatmap

# %%
plt.figure(figsize=(80,80))
sns.heatmap(train_v.corr(), annot = True, cmap='coolwarm');

# %% [markdown]
# #### Visualizing the top 10 strongest correlations

# %%
train_v.corr()[['SalePrice']].sort_values(by=['SalePrice'],ascending=False).head(10)
# Out:
#                SalePrice
# SalePrice       1.000000
# Overall Qual    0.800207
# Exter Qual      0.712146
# Gr Liv Area     0.697038
# Kitchen Qual    0.692336
# Garage Area     0.649897
# Garage Cars     0.647781
# Total Bsmt SF   0.629303
# 1st Flr SF      0.618486
# Bsmt Qual       0.612188

# %%
plt.figure(figsize=(6,15))
sns.heatmap(train_v.corr().abs()[['SalePrice']].sort_values(by=['SalePrice'],ascending=False), annot = True, cmap='coolwarm');

# %% [markdown]
# #### Checking the distribution of prices for all houses

# %%
plt.hist(train_v['SalePrice'], color='peru');

# %% [markdown]
# #### Checking some box plots for the different correlations

# %% [markdown]
# Note: The scatterplots and boxplots reveal outliers that I later removed to improve my model.

# %% [markdown]
# #### Looking at the overall rating

# %%
sns.boxplot(train_v['Overall Qual'], train_v['SalePrice'], palette='Pastel2');

# %%
sns.boxplot(train_v['Overall Cond'], train_v['SalePrice'], palette='Pastel2');

# %%
sns.boxplot(train_v['Exter Qual'], train_v['SalePrice'], palette='Pastel2');

# %%
sns.boxplot(train_v['Exter Cond'], train_v['SalePrice'], palette = 'Pastel2');

# %% [markdown]
# #### Looking at the area

# %%
sns.pairplot(train_v, x_vars=['Lot Area', 'Total Bsmt SF', 
                              'Gr Liv Area', 'Garage Area'], y_vars=['SalePrice'], height=5, aspect=.9);

# %% [markdown]
# #### Looking at the garage

# %%
sns.boxplot(train_v['Garage Type'], train_v['SalePrice'], palette = 'tab20');

# %%
sns.boxplot(train_v['Garage Cars'], train_v['SalePrice'], palette='tab20');

# %%
sns.boxplot(train_v['Garage Finish'], train_v['SalePrice'], palette='tab20');

# %%
sns.boxplot(train_v['Garage Qual'], train_v['SalePrice'], palette='tab20');

# %%
sns.boxplot(train_v['Garage Cond'], train_v['SalePrice'], palette='tab20');

# %%
sns.pairplot(train_v, x_vars=['Garage Area'], y_vars=['SalePrice'], height=5, aspect=.9);

# %% [markdown]
# #### Looking at the Kitchen

# %%
sns.boxplot(train_v['Kitchen AbvGr'], train_v['SalePrice'], palette='Spectral');

# %%
sns.boxplot(train_v['Kitchen Qual'], train_v['SalePrice'], palette='Spectral');

# %% [markdown]
# #### Looking at the Basement

# %%
sns.boxplot(train_v['BsmtFin Type 1'], train_v['SalePrice'], palette='twilight_shifted');

# %%
sns.boxplot(train_v['BsmtFin Type 2'], train_v['SalePrice'], palette = 'twilight_shifted');

# %%
sns.boxplot(train_v['Bsmt Qual'], train_v['SalePrice'], palette = 'magma');

# %%
sns.boxplot(train_v['Bsmt Cond'], train_v['SalePrice'], palette = 'magma');

# %%
sns.boxplot(train_v['Bsmt Exposure'], train_v['SalePrice'], palette = 'magma');

# %% [markdown]
# #### Looking at the neighborhood

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(train_v['Neighborhood'], train_v['SalePrice'], palette = 'magma', orient='v')
plt.xticks(rotation=60);
